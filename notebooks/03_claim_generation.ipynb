# %% [markdown]
# # Claim Generation
#
# This notebook will create short claims that can be checked against a chart.

# %%
from src.claims import (
    make_refuted_claim,
    make_supported_claim,
    make_unknown_claim,
)

print(make_supported_claim("Bulgaria", 2020, 2021))
print(make_refuted_claim("Bulgaria", 2020, 2021))
print(make_unknown_claim("Bulgaria", 2027))

# %% [markdown]
# ## Planned claim types
#
# - Higher or lower value
# - Increase or decrease
# - Maximum or minimum
# - Comparison between two countries
# - Future statement not supported by the chart
