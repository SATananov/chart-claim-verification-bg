# %% [markdown]
# # Final Results
#
# This notebook will contain only results produced by completed experiments.

# %% [markdown]
# ## Model comparison
#
# | Model | Accuracy | Macro F1 |
# |---|---:|---:|
# | Majority baseline | Not run | Not run |
# | Text baseline | Not run | Not run |
# | Text Keras model | Not run | Not run |
# | Image Keras model | Not run | Not run |
# | Multimodal model | Not run | Not run |

# %% [markdown]
# ## Conclusions
#
# To be written after the final test results are available.

# %% [markdown]
# ## Limitations
#
# To be written after the error analysis is complete.
